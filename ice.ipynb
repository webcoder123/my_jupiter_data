# %% [markdown]
# <a href="https://colab.research.google.com/github/webcoder123/my_jupiter_data/blob/main/ice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/contentdrive/MyDrive/Roushan/ice.csv")

# %%
data.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
data.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
data.shape # Get the number of rows and columns
data.shape[0] # Get the number of rows only
data.shape[1] # Get the number of columns only
# Out:
# 2

# %%
data[['Temperature', 'Revenue']]
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %%
data[['Temperature','Revenue']].plot.line()
# Out:
# <Axes: >

# %%
data['Revenue'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000
